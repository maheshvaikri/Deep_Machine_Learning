# %% [markdown]
# ## Algorithm Basics with Big -O Notation - Simple Explanation

# %% [markdown]
# #### Simple Function adding 0 to n in two different function definitions

# %%
def sum1(n):
    final_sum = 0
    for i in range(n+1):
        final_sum += i
    return final_sum

# %%
sum1(10)
# Out:
# 55

# %%
def sum2(n):
    return (n*(n+1))/2

# %%
sum2(10)
# Out:
# 55.0

# %% [markdown]
# ### Lets time the functions to determine the best algorithm

# %%
# %timeit sum1(100)
# Out:
# 100000 loops, best of 3: 8.78 µs per loop

# %%
# %timeit sum2(100)
# Out:
# The slowest run took 10.38 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 349 ns per loop

# %% [markdown]
# ## MatplotLib analysis of Big-O notations

# %%
from math import log
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

# Setup runtime comparison
n = np.linspace(1, 10, 1000)
labels = ['Constant','Logrithmic','Linear','Log Linear','Quadriatic','Cubic','Exponential']

big_o = [np.ones(n.shape), np.log(n), n, n*np.log(n), n**2, n**3, 2**n]

# Plot setup

plt.figure(figsize=(12,10))
plt.ylim(0,50)
plt.xlim(1,10)

for i in range (len(big_o)):
    plt.plot(n, big_o[i], label = labels[i])

plt.legend(loc=0)
plt.ylabel('Relative Runtime')
plt.xlabel('n')
